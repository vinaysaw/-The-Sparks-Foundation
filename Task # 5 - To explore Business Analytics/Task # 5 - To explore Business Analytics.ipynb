# %% [markdown]
# # Task 5-To explore business analytics

# %% [markdown]
# # Problem statement:

# %% [markdown]
# To Perform ‘Exploratory Data Analysis’ on the provided dataset ‘SampleSuperstore’
#
# You are the business owner of the retail firm and want to see how your company is performing.You are interested in finding out the weak areas where you can work to make more profit. What all business problems you can derive by looking into the data?

# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing the dataset

# %%
data = pd.read_csv("SampleSuperstore.csv")
data.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# # To check Null Values

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# # Checking the duplicate values

# %%
data.duplicated().sum()
# Out:
# 17

# %% [markdown]
# # Removing duplicate values

# %%
data = data.drop_duplicates()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9977 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9977 non-null   object
#  1   Segment       9977 non-null   object
#  2   Country       9977 non-null   object
#  3   City          9977 non-null   object
#  4   State         9977 non-null   object
#  5   Postal Code   9977 non-null   int64
#  6   Region        9977 non-null   object
#  7   Category      9977 non-null   object
#  8   Sub-Category  9977 non-null   object
#  9   Sales         9977 non-null   float64
#  10  Quantity      9977 non-null   int64
#  11  Discount      9977 non-null   float64
#  12  Profit        9977 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (9977, 13)

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %% [markdown]
# # Exploratory Data Analysis

# %%
corr = data.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize = (12, 7))
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# # Visualizing the data

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = data["Ship Mode"],order=(data['Ship Mode'].value_counts()).index)
plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = data["Segment"])
plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x=data['City'],order=(data['City'].value_counts().head(20)).index)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = data["State"],order=(data['State'].value_counts()).index)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = data["Region"],order=(data['Region'].value_counts()).index)
plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = data["Category"],order=(data['Category'].value_counts()).index)
plt.show()

# %%
plt.figure(figsize = (12, 7))
sns.countplot(x = data["Sub-Category"],order=(data['Sub-Category'].value_counts()).index)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12, 7))
plt.pie(data['Category'].value_counts(),labels= data['Category'].value_counts().index, startangle=90)
plt.title("Varous Categories")
plt.show()

# %%
state = data.groupby("State")[["Sales","Profit"]].sum().sort_values(by = "Sales", ascending = False)
plt.figure(figsize = (20,20))
state[:25].plot(kind = "bar",color = ["k","red"],edgecolor = "#0000FF")
plt.title("Profit Or Loss & Sales of top 25 States")
plt.xlabel("States")
plt.ylabel("Total profit / loss and Sales")
plt.grid(True)
state[25:].plot(kind = "bar",color = ["k","red"],edgecolor = "#0000FF")
plt.title("Profit Or Loss & Sales of the least economic States")
plt.xlabel("States")
plt.ylabel("Total profit / loss and Sales")
plt.grid(True)

# %%
data.groupby('Sub-Category')['Profit','Sales'].sum().plot.bar(color = ['b','k'])
# Out:
# C:\Users\vinay\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
pd.DataFrame(data.groupby('State').sum())['Profit'].sort_values(ascending=True)
# Out:
# State
# Texas                  -25750.9833
# Ohio                   -16959.3178
# Pennsylvania           -15565.4035
# Illinois               -12601.6500
# North Carolina          -7490.9122
# Colorado                -6527.8579
# Tennessee               -5341.6936
# Arizona                 -3427.9246
# Florida                 -3399.3017
# Oregon                  -1194.0993
# Wyoming                   100.1960
# West Virginia             185.9216
# North Dakota              230.1497
# South Dakota              394.8283
# Maine                     454.4862
# Idaho                     826.7231
# Kansas                    836.4435
# District of Columbia     1059.5893
# New Mexico               1157.1161
# Iowa                     1183.8119
# New Hampshire            1706.5028
# South Carolina           1769.0566
# Montana                  1833.3285
# Nebraska                 2037.0942
# Louisiana                2196.1023
# Vermont                  2244.9783
# ...

# %%
pd.DataFrame(data.groupby('State').sum())['Discount'].sort_values(ascending=True)
# Out:
# State
# Alabama                   0.00
# Missouri                  0.00
# Maine                     0.00
# Louisiana                 0.00
# Kentucky                  0.00
# Kansas                    0.00
# Iowa                      0.00
# Indiana                   0.00
# Wisconsin                 0.00
# Mississippi               0.00
# Nebraska                  0.00
# North Dakota              0.00
# District of Columbia      0.00
# Oklahoma                  0.00
# South Carolina            0.00
# South Dakota              0.00
# Vermont                   0.00
# Arkansas                  0.00
# Virginia                  0.00
# Georgia                   0.00
# Minnesota                 0.00
# Wyoming                   0.20
# West Virginia             0.30
# New Hampshire             0.30
# Maryland                  0.60
# Connecticut               0.60
# New Jersey                0.60
# Delaware                  0.60
# Montana                   1.00
# Rhode Island              1.20
# ...

# %%
plt.figure(figsize = (10,4))
sns.lineplot('Discount', 'Profit', data = data, color = 'r', label= 'Discount')
plt.legend()

# %% [markdown]
# *From the above study, when the profits of a state are compared with the discount provided in each state, the states which allowed more discount, went in loss and the above graph we conclude that THE PROFIT DECREASES WITH THE INCREASE IN DISCOUNT.

# %% [markdown]
# # 1. From the above data office supplies are good. We need to concentrate on Furniture and Technology category of business.

# %% [markdown]
# # 2. The Shipmode for the 'Same day' need to improved

# %% [markdown]
# # 3. There is a huge loss in Bookcases, Tables and Suppliers provided by the company

# %% [markdown]
# # 4. Company have lots of profite in sale in copier but the number of sales is very less so their is need of increase number of sales os copier

# %% [markdown]
# # 5. Profit and Discount show very weak and negative relationship. That should be kept in mind before taking any other decision related to business.

# %% [markdown]
# # 6. Sales of bookcase and tables are but the profite is in negative in both cases. Company facing loss in these two products.

# %% [markdown]
# # 7. The company facing loss in top 25 states in compare to least economic states.
